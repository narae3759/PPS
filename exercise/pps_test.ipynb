# %%
import olefile
import pandas as pd
# Out:
# Running cells with 'test (Python 3.10.14)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n test ipykernel --update-deps --force-reinstall'

# %%
hwpfile = olefile.OleFileIO("./한글파일.hwp")
encoded_text= hwpfile.openstream("PrvText").read()
decoded_text = encoded_text.decode("UTF-16")

decoded_text
# Out:
# '<Ⅰ. 품목개요서 및 RFP>\r\n<품목번호><2024-조선해양-일반-13><산업 기술 분류><중분류Ⅰ><중분류Ⅱ>\r\n<품목유형><■ 원천기술   □ 혁신제품><조선/해양시스템><->\r\n<융합유형><□ 산업고도화형 □ 사회문제해결형  ■ 신산업창출형  □ 해당없음>\r\n<해당여부><■ IP R&D연계  □ 표준연계  □ 디자인연계  □ BI연계  □ 경쟁형R&D  □ 복수형 R&D □ 국가핵심기술  □ 서비스형  □ 안전과제  ■ 탄소중립  ■ 국제공동 R&D □ 원스톱형  □ 통합형  ■ 초격차>\r\n<R&D자율성트랙 유형><■ R&D자율성트랙(일반)  □ R&D자율성트랙(지정) >\r\n<품목명><암모니아/수소 공급을 위한 FSRU 핵심 재기화기 및 개질기 개발><품목코드 (HSK10)><류><호><소호><통계부호><8><9><0><5><9><0><9><0><0><0><2><4><0><4><1><0><0><0><0><0><(TRL :  [시작] 3단계 〜 [종료] 5단계)><2><8><1><4><2><0><0><0><0><0>\r\n< 1. 개념 및 개발내용><>\r\n<□ 개념   ㅇ 액체 암모니아의 재기화, 암모니아 분해 기술(Ammonia Cracking)을 탑재하여 무탄소 가스연료(암모니아, 수소)의 외부 공급이 가능한 무탄소 연료 FSRU(Floating Storage Re-gasification Unit)의 핵심 기술 개발    <* 핵심 목표 : 암모니아 분해율 98% 이상 모듈 탑재 암모니아 FSRU 개발>  □ 개발내용     ㅇ 암모니아 FSRU의 암모니아 재기화(Re-gasification) 및 저장·공급 기술 개발  ㅇ 고순도 수소생산을 위한 암모니아 분해(Ammonia Cracking) 장비 기술 개발  ㅇ 에너지 효율 극대화를 위한 열교환기 기술 개발  ㅇ 재기화-분해 연계 육상 파일럿 규모 실증  ㅇ 암모니아 크래킹 기술 안전 및 성능 기준 개발 <연구개발계획서 제출시 정량적 목표치 및 상용화 수준 제시 필수 파일럿 실증 암모니아 및 수소 공급량, 수소 순도, 에너지 효율 국제공동연구>'

# %%
decoded_text

# %%
import pandas as pd

pd.DataFrame(items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 pd.DataFrame(items)
#
# NameError: name 'items' is not defined

# %%
import numpy as np

df = pd.DataFrame({
         'unif': np.random.uniform(-3, 3, 20),
         'norm': np.random.normal(0, 1, 20)
    })
print(df.head())
# Out:
#        unif      norm
# 0  1.602619 -1.898182
# 1  2.174404  0.680147
# 2 -0.924142  0.540775
# 3  1.223094 -0.335141
# 4  2.507448 -1.445414

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df.index = pd.date_range('2000', freq='YE', periods=df.shape[0])
df.plot()
# Out:
# <Axes: >
